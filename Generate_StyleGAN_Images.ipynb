# %% [markdown]
# <a href="https://colab.research.google.com/github/thinhngu/kit_old_gitlab/blob/master/Generate_StyleGAN_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 125, done.
# remote: Total 125 (delta 0), reused 0 (delta 0), pack-reused 125
# Receiving objects: 100% (125/125), 1.12 MiB | 7.21 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
cd stylegan2-ada-pytorch/
# Out:
# /content/stylegan2-ada-pytorch

# %%
pip install ninja opensimplex
# Out:
# ...
#      |████████████████████████████████| 108 kB 5.5 MB/s
# ...

# %%
# !python generate.py --outdir=/content/drive/MyDrive/Dataset/MixedTraining/Pitting/100 --trunc=1 --seeds=0-10850 --network=/content/drive/MyDrive/Dataset/Pretrained_Model/PITTING_TransferOpenTech_FID69.pkl
# Out:
# Streaming output truncated to the last 5000 lines.
# Generating image for seed 5851 (5851/10851) ...
# Generating image for seed 5852 (5852/10851) ...
# Generating image for seed 5853 (5853/10851) ...
# Generating image for seed 5854 (5854/10851) ...
# Generating image for seed 5855 (5855/10851) ...
# Generating image for seed 5856 (5856/10851) ...
# Generating image for seed 5857 (5857/10851) ...
# Generating image for seed 5858 (5858/10851) ...
# Generating image for seed 5859 (5859/10851) ...
# Generating image for seed 5860 (5860/10851) ...
# Generating image for seed 5861 (5861/10851) ...
# Generating image for seed 5862 (5862/10851) ...
# Generating image for seed 5863 (5863/10851) ...
# Generating image for seed 5864 (5864/10851) ...
# Generating image for seed 5865 (5865/10851) ...
# Generating image for seed 5866 (5866/10851) ...
# Generating image for seed 5867 (5867/10851) ...
# Generating image for seed 5868 (5868/10851) ...
# ...
