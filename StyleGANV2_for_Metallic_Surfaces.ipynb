# %% [markdown]
# <a href="https://colab.research.google.com/github/thinhngu/kit_old_gitlab/blob/master/StyleGANV2_for_Metallic_Surfaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install torch

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 125, done.
# remote: Total 125 (delta 0), reused 0 (delta 0), pack-reused 125
# Receiving objects: 100% (125/125), 1.12 MiB | 3.42 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
cd stylegan2-ada-pytorch/
# Out:
# /content/stylegan2-ada-pytorch/stylegan2-ada-pytorch/stylegan2-ada-pytorch

# %%
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git pull
# !git checkout origin/main -- train.py generate.py
# Out:
# Already up to date.

# %%
pip install ninja opensimplex

# %%
# !nvidia-smi
# Out:
# Tue Jun 15 12:15:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
#--resume /content/drive/MyDrive/Dataset/Pretrained_Model/cifar10u-cifar-ada-best-fid.pkl

# %%
# !python train.py --data /content/drive/MyDrive/Dataset/prepared_data --outdir /content/drive/MyDrive/Dataset/Generated_Colab_Data/ --snap=1d6 --kimg=1000 --resume /content/drive/MyDrive/Dataset/Pretrained_Model/network-snapshot-000704.pkl
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 16,
#   "network_snapshot_ticks": 16,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/Dataset/prepared_data",
#     "use_labels": false,
#     "max_size": 11075,
#     "xflip": false,
#     "resolution": 128
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
# ...

# %% [markdown]
# [Linktext](https://)# Neuer Abschnitt
